# %%
import pandas as pd

# %%
data=pd.read_csv('automobiles.csv')

# %%
data
# Out:
#     Unnamed: 0  index        company   body-style  wheel-base  length  \
# 0            0      0    alfa-romero  convertible        88.6   168.8
# 1            1      1    alfa-romero  convertible        88.6   168.8
# 2            2      2    alfa-romero    hatchback        94.5   171.2
# 3            3      3           audi        sedan        99.8   176.6
# 4            4      4           audi        sedan        99.4   176.6
# 5            5      5           audi        sedan        99.8   177.3
# 6            6      6           audi        wagon       105.8   192.7
# 7            7      9            bmw        sedan       101.2   176.8
# 8            8     10            bmw        sedan       101.2   176.8
# 9            9     11            bmw        sedan       101.2   176.8
# 10          10     13            bmw        sedan       103.5   189.0
# 11          11     14            bmw        sedan       103.5   193.8
# ...

# %% [markdown]
# ### Question 1 : Commencer par vérifier le type de données et afficher les 5 premières lignes du jeu de données.

# %%
data.dtypes
# Out:
# Unnamed: 0            int64
# index                 int64
# company              object
# body-style           object
# wheel-base          float64
# length              float64
# engine-type          object
# num-of-cylinders     object
# horsepower            int64
# average-mileage       int64
# price               float64
# dtype: object

# %%
data.head()
# Out:
#    Unnamed: 0  index      company   body-style  wheel-base  length  \
# 0           0      0  alfa-romero  convertible        88.6   168.8
# 1           1      1  alfa-romero  convertible        88.6   168.8
# 2           2      2  alfa-romero    hatchback        94.5   171.2
# 3           3      3         audi        sedan        99.8   176.6
# 4           4      4         audi        sedan        99.4   176.6
#
#   engine-type num-of-cylinders  horsepower  average-mileage    price
# 0        dohc             four         111               21  13495.0
# 1        dohc             four         111               21  16500.0
# 2        ohcv              six         154               19  16500.0
# 3         ohc             four         102               24  13950.0
# 4         ohc             five         115               18  17450.0

# %% [markdown]
# ### Question 2 : Ensuite, nettoyer les données en éliminant les valeurs NaN et 0 et reporter une nouvelle version dans le même fichier.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        58 non-null     int64
#  1   index             58 non-null     int64
#  2   company           58 non-null     object
#  3   body-style        58 non-null     object
#  4   wheel-base        58 non-null     float64
#  5   length            58 non-null     float64
#  6   engine-type       58 non-null     object
#  7   num-of-cylinders  58 non-null     object
#  8   horsepower        58 non-null     int64
#  9   average-mileage   58 non-null     int64
#  10  price             58 non-null     float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 5.1+ KB

# %% [markdown]
# ### Question 3 : Afficher le détail de toutes les voitures de marque Toyota

# %%
dataset = data[data['company']=='toyota']
dataset
# Out:
#     Unnamed: 0  index company body-style  wheel-base  length engine-type  \
# 45          45     66  toyota  hatchback        95.7   158.7         ohc
# 46          46     67  toyota  hatchback        95.7   158.7         ohc
# 47          47     68  toyota  hatchback        95.7   158.7         ohc
# 48          48     69  toyota      wagon        95.7   169.7         ohc
# 49          49     70  toyota      wagon        95.7   169.7         ohc
# 50          50     71  toyota      wagon        95.7   169.7         ohc
# 51          51     79  toyota      wagon       104.5   187.8        dohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 45             four          62               35   5348.0
# 46             four          62               31   6338.0
# 47             four          62               31   6488.0
# 48             four          62               31   6918.0
# 49             four          62               27   7898.0
# ...

# %% [markdown]
# ### Question 4 : Afficher le nom de la compagnie, le nombre de chevaux ainsi que le prix de la voiture la plus chère

# %%
datacamp = data.loc[:,['company','horsepower','price']]
datacamp
# Out:
#           company  horsepower    price
# 0     alfa-romero         111  13495.0
# 1     alfa-romero         111  16500.0
# 2     alfa-romero         154  16500.0
# 3            audi         102  13950.0
# 4            audi         115  17450.0
# 5            audi         110  15250.0
# 6            audi         110  18920.0
# 7             bmw         101  16430.0
# 8             bmw         101  16925.0
# 9             bmw         121  20970.0
# 10            bmw         182  30760.0
# 11            bmw         182  41315.0
# 12            bmw         182  36880.0
# 13      chevrolet          48   5151.0
# 14      chevrolet          70   6295.0
# 15      chevrolet          70   6575.0
# 16          dodge          68   6377.0
# 17          dodge          68   6229.0
# 18          honda          76   7295.0
# 19          honda         101  12945.0
# 20          honda         100  10345.0
# 21          isuzu          78   6785.0
# 22         jaguar         176  32250.0
# ...

# %%
datahonda = datacamp[datacamp['company']=='honda'].max()

# %%
datahonda
# Out:
# company         honda
# horsepower        101
# price         12945.0
# dtype: object

# %% [markdown]
# ### Question 5 : Afficher le nombre de voitures par compagnie

# %%
datacompte= data['company'].count

# %%
datacompte
# Out:
# <bound method Series.count of 0       alfa-romero
# 1       alfa-romero
# 2       alfa-romero
# 3              audi
# 4              audi
# 5              audi
# 6              audi
# 7               bmw
# 8               bmw
# 9               bmw
# 10              bmw
# 11              bmw
# 12              bmw
# 13        chevrolet
# 14        chevrolet
# 15        chevrolet
# 16            dodge
# 17            dodge
# 18            honda
# 19            honda
# 20            honda
# 21            isuzu
# 22           jaguar
# 23           jaguar
# 24           jaguar
# 25            mazda
# 26            mazda
# 27            mazda
# 28            mazda
# 29            mazda
# 30    mercedes-benz
# 31    mercedes-benz
# 32    mercedes-benz
# 33    mercedes-benz
# 34       mitsubishi
# 35       mitsubishi
# 36       mitsubishi
# 37       mitsubishi
# 38           nissan
# 39           nissan
# 40           nissan
# 41           nissan
# 42           nissan
# 43          porsche
# ...
